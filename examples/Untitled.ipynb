# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(-10, 10, 1000)

# %%
y = np.sin(x)

# %% [markdown]
# # Ola, isto é um cabeçalho
#
# $ y = 2x+b $

# %%
plt.plot(x,y);

# %% [markdown]
# ![aqi](https://www.catster.com/wp-content/uploads/2018/05/A-gray-cat-crying-looking-upset.jpg)
